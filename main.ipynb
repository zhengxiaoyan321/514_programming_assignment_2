# %%
# %load_ext autoreload
# %autoreload 2

# %%
import kNN
import decisionTree
import preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Preprocessing

# %%
[[HK_train, HK_test], [MY_train, MY_test], [OQ_train, OQ_test]] = preprocessing.preprocessing()
[multi_train, multi_test] = preprocessing.multi_class_preprocessing()

# %% [markdown]
# # Cross Validation without dimensional reduction

# %% [markdown]
# ## kNN tuning for k

# %%
k_list = np.arange(1,10)
scores=kNN.tune_k(HK_train, k_list)
plt.scatter(k_list, scores)
plt.xlabel('k')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_k(MY_train, k_list)
plt.scatter(k_list, scores)
plt.xlabel('k')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_k(OQ_train, k_list)
plt.scatter(k_list, scores)
plt.xlabel('k')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_k(multi_train, k_list)
plt.scatter(k_list, scores)
plt.xlabel('k')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# ## kNN tuning for metric

# %%
metric_list=np.arange(1,6)
scores=kNN.tune_metric(HK_train, metric_list)
plt.scatter(metric_list, scores)
plt.xlabel('metric')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_metric(MY_train, metric_list)
plt.scatter(metric_list, scores)
plt.xlabel('metric')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_metric(OQ_train, metric_list)
plt.scatter(metric_list, scores)
plt.xlabel('metric')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_metric(multi_train, metric_list)
plt.scatter(metric_list, scores)
plt.xlabel('metric')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# ## Decision Tree tuning for splitting criteria

# %%
criteria = ["gini", "entropy", "log_loss"]
scores=decisionTree.tune_criterion(HK_train, criteria)
plt.scatter(criteria, scores)
plt.xlabel('criteria')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_criterion(MY_train, criteria)
plt.scatter(criteria, scores)
plt.xlabel('criteria')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_criterion(OQ_train, criteria)
plt.scatter(criteria, scores)
plt.xlabel('criteria')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_criterion(multi_train, criteria)
plt.scatter(criteria, scores)
plt.xlabel('criteria')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# ## Decision Tree tuning for max depth

# %%
depth = np.arange(5,15)
scores=decisionTree.tune_max_depth(HK_train, depth)
plt.scatter(depth, scores)
plt.xlabel('depth')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_max_depth(MY_train, depth)
plt.scatter(depth, scores)
plt.xlabel('depth')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_max_depth(OQ_train, depth)
plt.scatter(depth, scores)
plt.xlabel('depth')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_max_depth(multi_train, depth)
plt.scatter(depth, scores)
plt.xlabel('depth')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# # Cross Validation with dimensional reduction

# %% [markdown]
# ## kNN tuning for k

# %%
HK_reduced = kNN.dimensionReduction(HK_train)
scores=kNN.tune_k(HK_reduced, k_list)
plt.scatter(k_list, scores)
plt.xlabel('k')
plt.ylabel('scores')
plt.show()

# %%
MY_reduced = kNN.dimensionReduction(MY_train)
scores=kNN.tune_k(MY_reduced, k_list)
plt.scatter(k_list, scores)
plt.xlabel('k')
plt.ylabel('scores')
plt.show()

# %%
OQ_reduced = kNN.dimensionReduction(OQ_train)
scores=kNN.tune_k(OQ_reduced, k_list)
plt.scatter(k_list, scores)
plt.xlabel('k')
plt.ylabel('scores')
plt.show()

# %%
reduced = kNN.dimensionReduction(multi_train)
scores=kNN.tune_k(reduced, k_list)
plt.scatter(k_list, scores)
plt.xlabel('k')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# ## kNN tuning for metric

# %%
scores=kNN.tune_metric(HK_reduced, metric_list)
plt.scatter(metric_list, scores)
plt.xlabel('metric')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_metric(MY_reduced, metric_list)
plt.scatter(metric_list, scores)
plt.xlabel('metric')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_metric(OQ_reduced, metric_list)
plt.scatter(metric_list, scores)
plt.xlabel('metric')
plt.ylabel('scores')
plt.show()

# %%
scores=kNN.tune_metric(reduced, metric_list)
plt.scatter(metric_list, scores)
plt.xlabel('metric')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# ## Decision Tree tuning for splitting criteria

# %%
HK_reduced_dt = decisionTree.dimensionReduction(HK_train)
scores=decisionTree.tune_criterion(HK_reduced_dt, criteria)
plt.scatter(criteria, scores)
plt.xlabel('criteria')
plt.ylabel('scores')
plt.show()

# %%
MY_reduced_dt = decisionTree.dimensionReduction(MY_train)
scores=decisionTree.tune_criterion(MY_reduced_dt, criteria)
plt.scatter(criteria, scores)
plt.xlabel('criteria')
plt.ylabel('scores')
plt.show()

# %%
OQ_reduced_dt = decisionTree.dimensionReduction(OQ_train)
scores=decisionTree.tune_criterion(OQ_reduced_dt, criteria)
plt.scatter(criteria, scores)
plt.xlabel('criteria')
plt.ylabel('scores')
plt.show()

# %%
reduced_dt = decisionTree.dimensionReduction(multi_train)
scores=decisionTree.tune_criterion(reduced_dt, criteria)
plt.scatter(criteria, scores)
plt.xlabel('criteria')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# ## Decision Tree tuning for max depth

# %%
scores=decisionTree.tune_max_depth(HK_reduced, depth)
plt.scatter(depth, scores)
plt.xlabel('depth')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_max_depth(MY_reduced, depth)
plt.scatter(depth, scores)
plt.xlabel('depth')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_max_depth(OQ_reduced, depth)
plt.scatter(depth, scores)
plt.xlabel('depth')
plt.ylabel('scores')
plt.show()

# %%
scores=decisionTree.tune_max_depth(reduced, depth)
plt.scatter(depth, scores)
plt.xlabel('depth')
plt.ylabel('scores')
plt.show()

# %% [markdown]
# # Final models and Performance Comparison

# %%
import time

# %%
knn_times=[]
knn_scores=[]

start_time = time.time()
knn_HK = kNN.train(HK_train, 1, 1)
knn_times.append(time.time() - start_time)
knn_scores.append(kNN.eval(knn_HK, HK_test))

start_time = time.time()
knn_MY = kNN.train(MY_train, 1, 1)
knn_times.append(time.time() - start_time)
knn_scores.append(kNN.eval(knn_MY, MY_test))

start_time = time.time()
knn_OQ = kNN.train(OQ_train, 1, 2)
knn_times.append(time.time() - start_time)
knn_scores.append(kNN.eval(knn_OQ, OQ_test))

start_time = time.time()
knn_full = kNN.train(multi_train, 1, 1)
knn_times.append(time.time() - start_time)
knn_scores.append(kNN.eval(knn_full, multi_test))

# %%
dt_times=[]
dt_scores=[]

start_time = time.time()
dt_HK = decisionTree.train(HK_train, criterion="gini", max_depth=11)
dt_times.append(time.time() - start_time)
dt_scores.append(decisionTree.eval(dt_HK, HK_test))

start_time = time.time()
dt_MY = decisionTree.train(MY_train, criterion="gini", max_depth=7)
dt_times.append(time.time() - start_time)
dt_scores.append(decisionTree.eval(dt_MY, MY_test))

start_time = time.time()
dt_OQ = decisionTree.train(OQ_train, criterion="gini", max_depth=13)
dt_times.append(time.time() - start_time)
dt_scores.append(decisionTree.eval(dt_OQ, OQ_test))

start_time = time.time()
dt_full = decisionTree.train(multi_train, criterion="log_loss", max_depth=14)
dt_times.append(time.time() - start_time)
dt_scores.append(decisionTree.eval(dt_full, multi_test))

# %%
results=pd.DataFrame(
{
    "knn times" : knn_times,
    "knn scores" : knn_scores, 
    "Decision Tree times" : dt_times,
    "Decision Tree scores" : dt_scores
},
index=pd.Index(["HK", "MY", "OQ", "full"])
)

# %%
results
# Out:
#       knn times  knn scores  Decision Tree times  Decision Tree scores
# HK     0.008013    0.939189             0.013963              0.939189
# MY     0.005989    1.000000             0.010969              0.974684
# OQ     0.007874    0.974026             0.010969              0.922078
# full   0.013115    0.973856             0.037825              0.934641

# %%
knn_times=[]
knn_scores=[]

start_time = time.time()
knn_HK = kNN.train(HK_reduced, 1, 1)
knn_times.append(time.time() - start_time)
knn_scores.append(kNN.eval(knn_HK, HK_test[HK_reduced.columns]))

start_time = time.time()
knn_MY = kNN.train(MY_reduced, 3, 2)
knn_times.append(time.time() - start_time)
knn_scores.append(kNN.eval(knn_MY, MY_test[MY_reduced.columns]))

start_time = time.time()
knn_OQ = kNN.train(OQ_reduced, 3, 2)
knn_times.append(time.time() - start_time)
knn_scores.append(kNN.eval(knn_OQ, OQ_test[OQ_reduced.columns]))

start_time = time.time()
knn_full = kNN.train(reduced, 5, 1)
knn_times.append(time.time() - start_time)
knn_scores.append(kNN.eval(knn_full, multi_test[reduced.columns]))

# %%
dt_times=[]
dt_scores=[]

start_time = time.time()
dt_HK = decisionTree.train(HK_reduced_dt, criterion="gini", max_depth=12)
dt_times.append(time.time() - start_time)
dt_scores.append(decisionTree.eval(dt_HK, HK_test[HK_reduced_dt.columns]))

start_time = time.time()
dt_MY = decisionTree.train(MY_reduced_dt, criterion="entropy", max_depth=7)
dt_times.append(time.time() - start_time)
dt_scores.append(decisionTree.eval(dt_MY, MY_test[MY_reduced_dt.columns]))

start_time = time.time()
dt_OQ = decisionTree.train(OQ_reduced_dt, criterion="gini", max_depth=9)
dt_times.append(time.time() - start_time)
dt_scores.append(decisionTree.eval(dt_OQ, OQ_test[OQ_reduced_dt.columns]))

start_time = time.time()
dt_full = decisionTree.train(reduced_dt, criterion="gini", max_depth=12)
dt_times.append(time.time() - start_time)
dt_scores.append(decisionTree.eval(dt_full, multi_test[reduced_dt.columns]))

# %%
results=pd.DataFrame(
{
    "knn times" : knn_times,
    "knn scores" : knn_scores, 
    "Decision Tree times" : dt_times,
    "Decision Tree scores" : dt_scores
},
index=pd.Index(["HK", "MY", "OQ", "full"])
)
results
# Out:
#       knn times  knn scores  Decision Tree times  Decision Tree scores
# HK     0.014959    0.925676             0.007012              0.878378
# MY     0.012599    0.987342             0.004995              0.943038
# OQ     0.008978    0.922078             0.005954              0.805195
# full   0.020026    0.867102             0.012936              0.657952
